# %%
import pandas as pd
import numpy as np

# %%
train = pd.train_csv("")

# %%
#check types
train.dtypes

# %%
#if data with no int transform that with LabelEncoder or dummies
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
train.['Object type'] = lb.fit_transform(train['Object Type'])

# %%
#check for null value
train.isnull().any()

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
X = train.drop['Dependent Variable'] , axis = 1]
Y = train['Dependent Variable']

# %%
best_feature = SelectKBest(score_func=chi2, k=10)

# %%
# find feature score
fit = best_feature.fit(x,y)

# %%
dfscore = pd.DataFrame(fit.scores_) #score of the fits
dfcols = pd.DataFrame(x.columns) # column head of x

# %%
feature_score = pd.concat([dfcols, dfscore], axis = 1) # merge 2 coulumns 
feature_score.columns('Name 1', 'Name2') # giving heading of the columns

# %%
sorted_score = feature_score.sort_values(by = 'Name2')

# %%
x.drop(['Which', 'scores', 'are', 'very', 'low', 'for testing'], axis =1)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

# %%
rfc.fit(x,y)

# %%
x_test = pd.read('Test file.csv')

# %% [markdown]
# #drop same columns for x_test also preprocess like previous

# %%
prediction = reg.predict(x_test)  #generate prediction
pred_df = pd.DataFrame(prediction)  #make prediction as dataframe
pred_df.to_csv('Name of the file', index = False)
