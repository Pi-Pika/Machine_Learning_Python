# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df.head(3)
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['year']], df[['income']])
# Out:
# LinearRegression()

# %%
inc2025 = float(reg.predict([[2025]]))
inc2025
# Out:
# C:\Users\hasan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\hasan\AppData\Local\Temp\ipykernel_608\3791839064.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   inc2025 = float(reg.predict([[2025]]))
# 45431.01947053103

# %%
coef = float(reg.coef_)
coef
# Out:
# C:\Users\hasan\AppData\Local\Temp\ipykernel_608\3852127020.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   coef = float(reg.coef_)
# 828.4650752227104

# %%
intercept = float(reg.intercept_)
intercept
# Out:
# C:\Users\hasan\AppData\Local\Temp\ipykernel_608\1262493734.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   intercept = float(reg.intercept_)
# -1632210.7578554575

# %%
reg.score(df[['year']], df[['income']])
# Out:
# 0.890916917957032

# %%
import pickle

# %%
with open('model_pickle', 'wb') as f:
    pickle.dump(reg,f)

# %%
with open('model_pickle', 'rb') as f:
    mp = pickle.load(f)
mp.predict([[5000]])
# Out:
# C:\Users\hasan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2510114.61825809]])

# %%
import sklearn.externals 
import joblib

# %%
joblib.dump(reg, 'model_joblib')
# Out:
# ['model_joblib']

# %%
mj = joblib.load('model_joblib')

# %%
mj.predict([[5000]])
# Out:
# C:\Users\hasan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2510114.61825809]])
